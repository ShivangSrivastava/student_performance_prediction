# %%
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# /tmp/ipykernel_12371/1801383384.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('../data/Student_Marks.csv')
df.head()
# Out:
#    number_courses  time_study   Marks
# 0               3       4.508  19.202
# 1               4       0.096   7.734
# 2               4       3.133  13.811
# 3               6       7.909  53.018
# 4               8       7.811  55.299

# %%
any(df['Marks'].isna())
# Out:
# False

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(df['number_courses'],df['Marks'])

# %%
plt.scatter(df['time_study'],df['Marks'])

# %%
predict='Marks'
x=df.drop(predict,axis=1)
y=df[predict]

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression


model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test,y_test)
# Out:
# 0.9253760114641628

# %%
model.predict([[3,6]])
# Out:
# /home/shivang/codeX/student_performance_prediction/.venv/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([30.6041414])

# %%
import joblib


joblib.dump(model,"model.joblib")
# Out:
# ['model.joblib']

# %%
model.coef_,model.intercept_
# Out:
# (array([1.8692988 , 5.38476859]), -7.312366556446065)
